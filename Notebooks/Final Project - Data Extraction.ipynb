# %%
import tarfile
import pandas
import gzip

# %%
#tar = tarfile.open(name='chicago-complete.monthly.2020-03-01-to-2020-03-31.tar')

# %%
#tar.extractall()
#tar.close()

# %%
path = 'C:\\Users\\sampg\\OneDrive\\Documents\\UChicago\\Time Series\\Final Project\\TimeSeries-Grp5\\Data\\chicago-complete.monthly.2020-03-01-to-2020-03-31\\'

inputData = pandas.read_csv(path+'data.csv.gz',
                            delimiter = ',')

# %%
inputData.head(20)
# Out:
#               timestamp       node_id   subsystem         sensor  \
# 0   2020/03/01 00:00:00  001e06113a24  lightsense  apds_9006_020
# 1   2020/03/01 00:00:00  001e06113a24  lightsense        hih6130
# 2   2020/03/01 00:00:00  001e06113a24  lightsense        hih6130
# 3   2020/03/01 00:00:00  001e06113a24  lightsense       hmc5883l
# 4   2020/03/01 00:00:00  001e06113a24  lightsense       hmc5883l
# 5   2020/03/01 00:00:00  001e06113a24  lightsense       hmc5883l
# 6   2020/03/01 00:00:00  001e06113a24  lightsense         ml8511
# 7   2020/03/01 00:00:00  001e06113a24  lightsense       mlx75305
# 8   2020/03/01 00:00:00  001e06113a24  lightsense         tmp421
# 9   2020/03/01 00:00:00  001e06113a24  lightsense       tsl250rd
# 10  2020/03/01 00:00:00  001e06113a24  lightsense       tsl260rd
# 11  2020/03/01 00:00:00  001e06113a24    metsense         bmp180
# 12  2020/03/01 00:00:00  001e06113a24    metsense         bmp180
# 13  2020/03/01 00:00:00  001e06113a24    metsense        hih4030
# 14  2020/03/01 00:00:00  001e06113a24    metsense         htu21d
# 15  2020/03/01 00:00:00  001e06113a24    metsense         htu21d
# 16  2020/03/01 00:00:00  001e06113a24    metsense       metsense
# 17  2020/03/01 00:00:00  001e06113a24    metsense       mma8452q
# 18  2020/03/01 00:00:00  001e06113a24    metsense       mma8452q
# 19  2020/03/01 00:00:00  001e06113a24    metsense       mma8452q
#
#            parameter     value_raw     value_hrf
# 0          intensity             5         0.402
# 1           humidity          1906         11.63
# 2        temperature         26020         25.51
# 3   magnetic_field_x           297         270.0
# 4   magnetic_field_y            95        86.364
# 5   magnetic_field_z          -157      -160.204
# 6          intensity          9628        44.302
# 7          intensity           505        -1.919
# 8        temperature          5744         22.44
# 9          intensity          9628        23.416
# 10         intensity           301         0.703
# 11          pressure      10832416       1037.29
# 12       temperature         24955          29.1
# 13          humidity           486         73.76
# 14          humidity         25006         41.69
# 15       temperature         18420          2.54
# 16                id  01dcc6e21700  01dcc6e21700
# 17    acceleration_x         65360       -10.742
# 18    acceleration_y         49824      -958.984
# 19    acceleration_z           736        44.922

# %%
inputData.tail(20)
# Out:
#                     timestamp       node_id   subsystem         sensor  \
# 53760932  2020/03/31 23:59:59  001e0610ee43  lightsense       hmc5883l
# 53760933  2020/03/31 23:59:59  001e0610ee43  lightsense         ml8511
# 53760934  2020/03/31 23:59:59  001e0610ee43  lightsense       mlx75305
# 53760935  2020/03/31 23:59:59  001e0610ee43  lightsense         tmp421
# 53760936  2020/03/31 23:59:59  001e0610ee43  lightsense       tsl250rd
# 53760937  2020/03/31 23:59:59  001e0610ee43  lightsense       tsl260rd
# 53760938  2020/03/31 23:59:59  001e0610ee43    metsense         bmp180
# 53760939  2020/03/31 23:59:59  001e0610ee43    metsense         bmp180
# 53760940  2020/03/31 23:59:59  001e0610ee43    metsense        hih4030
# 53760941  2020/03/31 23:59:59  001e0610ee43    metsense         htu21d
# 53760942  2020/03/31 23:59:59  001e0610ee43    metsense         htu21d
# 53760943  2020/03/31 23:59:59  001e0610ee43    metsense       metsense
# 53760944  2020/03/31 23:59:59  001e0610ee43    metsense       mma8452q
# 53760945  2020/03/31 23:59:59  001e0610ee43    metsense       mma8452q
# 53760946  2020/03/31 23:59:59  001e0610ee43    metsense       mma8452q
# 53760947  2020/03/31 23:59:59  001e0610ee43    metsense        pr103j2
# 53760948  2020/03/31 23:59:59  001e0610ee43    metsense  spv1840lr5h_b
# 53760949  2020/03/31 23:59:59  001e0610ee43    metsense         tmp112
# 53760950  2020/03/31 23:59:59  001e0610ee43    metsense       tsl250rd
# 53760951  2020/03/31 23:59:59  001e0610ee43    metsense         tsys01
#
#                  parameter     value_raw     value_hrf
# 53760932  magnetic_field_z           -89       -90.816
# 53760933         intensity         32767       495.982
# 53760934         intensity          9424       197.166
# 53760935       temperature          8064          31.5
# 53760936         intensity         12369        30.107
# 53760937         intensity          9424         25.28
# 53760938          pressure      11229856       1005.25
# 53760939       temperature         20966           1.7
# 53760940          humidity           521         79.01
# 53760941          humidity         41770         73.67
# 53760942       temperature         19488           5.4
# 53760943                id  01b6c7141800  01b6c7141800
# 53760944    acceleration_x         65504        -1.953
# 53760945    acceleration_y         49392      -985.352
# 53760946    acceleration_z           512         31.25
# 53760947       temperature           657          4.35
# 53760948         intensity           NaN         56.72
# 53760949       temperature           753          5.88
# 53760950         intensity             3         0.151
# 53760951       temperature       9224062          5.01

# %%
inputData.shape
# Out:
# (53760952, 7)

# %%
inputData['timestamp'].describe()
# Out:
# count                53760952
# unique                1198190
# top       2020/03/27 01:53:29
# freq                      434
# Name: timestamp, dtype: object

# %%
inputData_Node = inputData.loc[inputData['node_id'].isin(['001e06113a24'])]

# %%
inputData_Node.shape
# Out:
# (207975, 7)

# %%
inputData['subsystem'].value_counts()
# Out:
# metsense      19451040
# lightsense    14523820
# chemsense      7081945
# plantower      4612020
# nc             3883617
# wagman         2585677
# ep             1018194
# alphasense      597444
# image             4964
# audio             2231
# Name: subsystem, dtype: int64
